# %% [markdown]
# <a href="https://colab.research.google.com/github/VarshaPesala/python-calculator/blob/main/Python_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

print("=== 🧮 Advanced Python Calculator ===")
print("Operations supported: +  -  *  /  **  √()  %")
print("Type 'exit' to quit.\n")

def calculate(expression):
    """Safely evaluate mathematical expressions."""
    try:
        expression = expression.replace("√", "math.sqrt")
        result = eval(expression, {"math": math, "__builtins__": None})
        return result
    except Exception as e:
        return f"Error: {e}"

while True:
    expr = input("Enter expression: ")

    if expr.lower() == "exit":
        print("Goodbye 👋")
        break

    print("Result =", calculate(expr))
# Out:
# === 🧮 Advanced Python Calculator ===
# Operations supported: +  -  *  /  **  √()  %
# Type 'exit' to quit.
#
# Enter expression: 2+3
# Result = 5
# Enter expression: 6*10
# Result = 60
# Enter expression: 3/2
# Result = 1.5
# Enter expression: exit
# Goodbye 👋
